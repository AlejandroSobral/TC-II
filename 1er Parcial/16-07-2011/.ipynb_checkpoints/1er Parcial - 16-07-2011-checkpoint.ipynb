# %% [markdown]
#  ### Ejercicio tipo parcial - TC2 16-07-2011
#
# <img src="./Consigna1.png" align="center" width="70%" />
# <img src="./Consigna2.png" align="center" width="70%" />

# %% [markdown]
# <img src="./1.png" align="center" width="50%" />
# <img src="./2.png" align="center" width="50%" />
# <img src="./3.png" align="center" width="50%" />
# <img src="./4.png" align="center" width="50%" />

# %% [markdown]
# <img src="./5.png" align="center" width="50%" />

# %% [markdown]
# B) F1(S) no podría corresponderse con una función de excitación, ya que no es FRP.
#    F2(S) podría ser una función de excitación.
#
# C)
#
# $$
# |F1(W)| = \frac{1}{(W+4)(W^2 +10W +9 }| W =3*2*pi
# \\
# $$
#
# $$
# |F1(W)| = -82dB
# \\
# $$
#
# $$
# fase(W) = -(arctg(\frac{W}{4})+arctg(\frac{W}{1})+arctg(\frac{W}{9}))| W =3*2*pi
# \\
# $$
# fase(W) = -75º
#
#
# No existe distorsión de fase, ya que posee una fase lineal.
#
# d) Repito C pero con W = 3 y W = 30? Yo entiendo que al no haber distorsión lineal, no deberían mezclarse.

# %%
import numpy as np
import scipy.signal as sig
from splane import analyze_sys
import matplotlib.pyplot as plt
from scipy.signal import TransferFunction
from splane import pzmap, grpDelay, bodePlot, convert2SOS

num = [1]
den = [1,14, 49,16]

filtro = TransferFunction(num, den)
bodePlot(filtro)
# Out:
# (1,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CBF2FAB448>,
# ...
#        dtype=object))
